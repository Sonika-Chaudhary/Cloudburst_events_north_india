# %% [markdown]
# # Combining Daily files into yearly netcdf files

# %%
import xarray as xr
import numpy as np

# %%
ds=xr.open_mfdataset(r"C:\Users\SONIKA\Desktop\Project Data\north_india_jaxa\north_india_jaxa\GSMaP.v7_0.10deg_2000*.nc") #opening all 2001 year data files together as a dask array
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 7344, lon: 90, lat: 90)
# Coordinates:
#   * time     (time) datetime64[ns] 2000-03-01 ... 2000-12-31T23:00:00
#   * lon      (lon) float64 72.05 72.15 72.25 72.35 ... 80.65 80.75 80.85 80.95
#   * lat      (lat) float64 36.95 36.85 36.75 36.65 ... 28.35 28.25 28.15 28.05
# Data variables:
#     pr       (time, lat, lon) float32 dask.array<chunksize=(24, 90, 90), meta=np.ndarray>
# Attributes:
#     CDI:          Climate Data Interface version 2.0.5 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Thu Sep 15 15:31:34 2022: cdo sellonlatbox,72,81,28,37 GSMa...
#     CDO:          Climate Data Operators version 2.0.5 (https://mpimet.mpg.de...

# %%
year= np.arange(2000,2021,1)                          #creating array with start 2000 ,end 2020 and difference 1

# %%
year
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2014, 2015, 2016, 2017, 2018, 2019, 2020])

# %%
for i in year:
    ds=xr.open_mfdataset(r"C:\Users\SONIKA\Desktop\Project Data\north_india_jaxa\north_india_jaxa\GSMaP.v7_0.10deg_" +str(i)+ "*.nc")  #opening yearwise netcdf files using dask array 
    ds.to_netcdf(r'C:\Users\SONIKA\Desktop\Yearly combined rainfall'+'\\' + str(i) +'.nc')   #converting dask array to netcdf

# %% [markdown]
# # Getting yearly cloudburst data with rainfall greater than 100 mm/hr

# %%
ds=xr.open_dataset(r'C:\Users\SONIKA\Desktop\Yearly combined rainfall\2000.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 7344, lon: 90, lat: 90)
# Coordinates:
#   * time     (time) datetime64[ns] 2000-03-01 ... 2000-12-31T23:00:00
#   * lon      (lon) float64 72.05 72.15 72.25 72.35 ... 80.65 80.75 80.85 80.95
#   * lat      (lat) float64 36.95 36.85 36.75 36.65 ... 28.35 28.25 28.15 28.05
# Data variables:
#     pr       (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 2.0.5 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Thu Sep 15 15:31:34 2022: cdo sellonlatbox,72,81,28,37 GSMa...
#     CDO:          Climate Data Operators version 2.0.5 (https://mpimet.mpg.de...

# %%
ds= ds.where(ds.pr>=100,drop=True)            #finding the places where precipitation exceded 100mm and droping the values which are lower 
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 15, lat: 43, lon: 62)
# Coordinates:
#   * time     (time) datetime64[ns] 2000-04-11T13:00:00 ... 2000-09-20T02:00:00
#   * lon      (lon) float64 72.05 72.15 72.25 72.35 ... 78.65 78.75 78.85 78.95
#   * lat      (lat) float64 34.05 33.85 33.75 33.65 ... 28.65 28.35 28.25 28.15
# Data variables:
#     pr       (time, lat, lon) float32 nan nan nan nan nan ... nan nan nan nan
# Attributes:
#     CDI:          Climate Data Interface version 2.0.5 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Thu Sep 15 15:31:34 2022: cdo sellonlatbox,72,81,28,37 GSMa...
#     CDO:          Climate Data Operators version 2.0.5 (https://mpimet.mpg.de...

# %%
ds =ds.to_dataframe()                                    #converting xarray to dataframe
ds
# Out:
#                                  pr
# time                lat   lon
# 2000-04-11 13:00:00 34.05 72.05 NaN
#                           72.15 NaN
#                           72.25 NaN
#                           72.35 NaN
#                           72.45 NaN
# ...                              ..
# 2000-09-20 02:00:00 28.15 78.55 NaN
#                           78.65 NaN
#                           78.75 NaN
#                           78.85 NaN
#                           78.95 NaN
#
# [39990 rows x 1 columns]

# %%
ds.to_excel(r"C:\Users\SONIKA\Desktop\2000_cloudburst_all.xlsx")     #onverting dataframe to excel file

# %%
ds=ds.dropna()                                 #droping the nan values observed and the resulting data are cloudburst data
ds
# Out:
#                                          pr
# time                lat   lon
# 2000-04-11 13:00:00 30.95 78.85  147.147446
#                     30.85 78.75  148.539276
#                           78.85  175.343582
#                           78.95  121.335083
# 2000-05-06 12:00:00 33.55 73.85  112.804665
# ...                                     ...
# 2000-09-20 02:00:00 30.55 76.55  159.999969
#                           76.65  159.999969
#                           76.75  159.999969
#                     30.45 76.15  159.999924
#                           76.55  159.999969
#
# [572 rows x 1 columns]

# %%
#ds.to_excel(r"C:\Users\SONIKA\Desktop\yearly cloudburst dataframe\2000_cloudburst.xlsx")

# %%
ds=xr.open_dataset(r'C:\Users\SONIKA\Desktop\Yearly combined rainfall\2014.nc')
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 8760, lon: 90, lat: 90)
# Coordinates:
#   * time     (time) datetime64[ns] 2014-01-01 ... 2014-12-31T23:00:00
#   * lon      (lon) float64 72.05 72.15 72.25 72.35 ... 80.65 80.75 80.85 80.95
#   * lat      (lat) float64 36.95 36.85 36.75 36.65 ... 28.35 28.25 28.15 28.05
# Data variables:
#     pr       (time, lat, lon) float32 ...
# Attributes:
#     CDI:          Climate Data Interface version 2.0.5 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Thu Sep 15 16:43:42 2022: cdo sellonlatbox,72,81,28,37 GSMa...
#     CDO:          Climate Data Operators version 2.0.5 (https://mpimet.mpg.de...

# %%
ds= ds.where(ds.pr>=100,drop=True)
ds
# Out:
# <xarray.Dataset>
# Dimensions:  (time: 0, lat: 0, lon: 0)
# Coordinates:
#   * time     (time) datetime64[ns]
#   * lon      (lon) float64
#   * lat      (lat) float64
# Data variables:
#     pr       (time, lat, lon) float32
# Attributes:
#     CDI:          Climate Data Interface version 2.0.5 (https://mpimet.mpg.de...
#     Conventions:  CF-1.6
#     history:      Thu Sep 15 16:43:42 2022: cdo sellonlatbox,72,81,28,37 GSMa...
#     CDO:          Climate Data Operators version 2.0.5 (https://mpimet.mpg.de...

# %% [markdown]
# ### Since 2014 has no cloudburst we excluded it from year array

# %%
year=np.array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
       2011, 2012, 2013, 2015, 2016, 2017, 2018, 2019, 2020])                    
year
# Out:
# array([2000, 2001, 2002, 2003, 2004, 2005, 2006, 2007, 2008, 2009, 2010,
#        2011, 2012, 2013, 2015, 2016, 2017, 2018, 2019, 2020])

# %% [markdown]
# ## Looping through all yearly rainfall data files created above and finding the cloudburst for each year in a seperate dataframe (excel file)

# %%
for i in year:
    ds=xr.open_dataset(r'C:\Users\SONIKA\Desktop\Yearly combined rainfall'+'\\'+str(i)+".nc")
    ds =ds.where(ds.pr>=100,drop=True).to_dataframe()
    ds=ds.dropna()
    ds.to_excel(r'C:\Users\SONIKA\Desktop\yearly cloudburst dataframe'+ '\\' + str(i) +'.xlsx')
